# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('ddddd.png')
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('ddddd.png')
#kernel = np.ones((5,5),np.float32)/25
#dst = cv2.filter2D(img,-1,kernel)
blur3 =cv2.GaussianBlur(img,(3,3))
blur5 =cv2.blur(img,(5,5))
MedianBlur5=cv2.medianBlur(img,5)
BilateralFilter=cv2.bilateralFilter(img,9,75,75)
plt.subplot(121),plt.imshow(MedianBlur5),plt.title('MedianBlur5')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(BilateralFilter),plt.title('BilateralFilter')
plt.xticks([]), plt.yticks([])
plt.show()
